# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install keras-metrics

# %%
import tqdm
import tensorflow as tf
import numpy as np
import keras_metrics # for recall and precision metrics
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.layers import Embedding, LSTM, Dropout, Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.model_selection import train_test_split
import time
import numpy as np
import pickle
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
df=data.dropna()
df.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label
# 0  Image copyright Getty Images\nOn Sunday mornin...      1
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1
# 2  The feud broke into public view last week when...      1
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1
# 4  Country singer Jason Aldean, who was performin...      1

# %%
df.Label.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
SEQUENCE_LENGTH = 100 # the length of all sequences (number of words per sample)
EMBEDDING_SIZE = 100  # Using 100-Dimensional GloVe embedding vectors
TEST_SIZE = 0.20 # ratio of testing set

BATCH_SIZE = 64
EPOCHS =30 # number of epochs

# to convert labels to integers and vice-versa
#label2int = {"truthful": 0, "deceptive": 1} #added
#int2label = {0: "truthful", 1: "deceptive"} #added

label2int = {'Real':1, 'Fake':0} #added
int2label = {0:'Fake', 1:'Real'} #added

# %%
x=df['Headline']

# %%
x
# Out:
# 0              Four ways Bob Corker skewered Donald Trump
# 1       Linklater's war veteran comedy speaks to moder...
# 2       Trump’s Fight With Corker Jeopardizes His Legi...
# 3       Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4             Jason Aldean opens 'SNL' with Vegas tribute
#                               ...
# 4003    CNN and Globalist Exposed - Steve Quayle and A...
# 4004                                      Trends to Watch
# 4005    Trump Jr. Is Soon To Give A 30-Minute Speech F...
# 4007    China to accept overseas trial data in bid to ...
# 4008    Vice President Mike Pence Leaves NFL Game Beca...
# Name: Headline, Length: 3988, dtype: object

# %%
x=list(x)

# %%
x
# Out:
# ['Four ways Bob Corker skewered Donald Trump',
#  "Linklater's war veteran comedy speaks to modern America, says star",
#  'Trump’s Fight With Corker Jeopardizes His Legislative Agenda',
#  "Egypt's Cheiron wins tie-up with Pemex for Mexican onshore oil field",
#  "Jason Aldean opens 'SNL' with Vegas tribute",
#  'JetNation FanDuel League; Week 4',
#  'Kansas Tried a Tax Plan Similar to Trump’s. It Failed.',
#  'India RBI chief: growth important, but not at cost of inflation - newspaper',
#  'EPA chief to sign rule on Clean Power Plan exit on Tuesday',
#  'Talks on sale of Air Berlin planes to easyJet at risk of collapse: report',
#  'U.S. President Donald Trump Quietly Signs Law To Allow Warrantless Searches In Parts Of VA, DC and MD',
#  '2017 Fantasy Football Team Defense Rankings - Week 5',
#  'Just Shut Up & Play Some Damn Baseball!!',
#  'Deloitte cyber attack affected up to 350 clients: Guardian',
#  '10/7: Chuck Axed; HBD Brickyard, Adam, Moonlight Ace & Chuck; AS; Season Finales...',
#  'Gunman’s Girlfriend Said She Didn’t Know He Planned Harm',
#  'Marilou Danley, Gunman’s Girlfriend, Says She Was Unaware of His Plans',
#  'Trump’s Immigration Rhetoric Echoes a Bitter Fight in the 90s',
#  'Trump Bemoans ‘Little Appreciation’ As San Juan Mayor Begs For Water',
#  "In Meeting With Military, Trump Talks Of 'Calm Before The Storm'",
#  'Teacher Sparks Outrage By Asking Kids To Make Nazi Mascots',
#  '9/28 Through the 40s: The Gloaming; HBD Bill, Lou, Cy the Third, Everett, Cy, Leon & Buck; Clarke Honored;Tiny 2-Hitter',
#  'Weinstein Co board ousts Harvey Weinstein after harassment allegations',
#  'Hillary Clinton Suggests That Trump May Order the Murder of Journalists',
#  '9/29 Through the 40s: HBD Cannonball & Paul, Camnitz Clan, Game Stories',
#  'Sharapova storms into Tianjin quarter-finals',
#  '10/3 Expo Park-Forbes Field Era: Pirates, Grays WS Win, Game Stories',
#  'Weinstein scandal no surprise to Hollywood',
#  'Blackhawks Roster Breakdown: Goalies',
#  'With Christian Pulisic Driving, United States Steers Closer to World Cup',
#  'CycleBar Westgate West Hosts Benefit Cycle Ride to Help ‘Fragile Bone Disease’ Foundation on Oct. 7',
#  'Kimmel gives an emotional plea to lawmakers',
#  "'Hard' Brexit seen dire for Dutch but far worse for Brits: Rabobank",
#  'Weakening Nate brings rain, tornado warnings to U.S. South',
#  'PA Attorney General Concerned About Equifax Cyberattack; Will U.S. Attorneys General Be Upset About Utility Smart Meters Hacking?',
#  "Melania Trump responds to Ivana Trump calling herself 'first lady'",
#  'Trump Administration Formally Lifts Sanctions on Sudan',
#  'Mexico plans aid for Puerto Rico after Hurricane Maria',
#  "10/1 Expo Park-Forbes Field Era: Deacon Whips Cy In 1st WS Game, Waner's 237 Hits, Boss Man Roberto & More",
#  'Five arrested in Delhi over assault on Nigerian',
#  'Google Clips Automatically Identifies Everyone Including Your Pets',
#  '2017 Fantasy Football Kicker Rankings - Week 4',
#  'A "problem" For The Wild Card Game & Sanchez...',
#  '2017 Fantasy Football Running Back Rankings - Week 5',
#  'What Would Happen To You in The Microwave?',
#  'Ravens vs. Steelers - Friday/Game Status',
#  'Upgrading to a Modern Mac',
#  'Newton Laughs at Female Reporter After Asking a Question About WR Routes',
#  'Las Vegas Police Deny NFL’s Michael Bennett Was Racially Profiled as Video Rebuts Player’s Claims',
#  "World Cup 2018: What are England boss Gareth Southgate's big challenges?",
#  '10/7: Chuck Axed; HBD Brickyard, Adam, Moonlight Ace & Chuck; AS; Season Finales...',
#  'Iran hardliners, pragmatists show unity in response to Trump',
#  'Pumpkin Spiced White Hot Chocolate',
#  'Duping Americans And Wasting Taxpayers’ Money',
#  'Nibiru Final Warning - ‘Just How Long Does Earth Have Left Before Planet X Doom’',
#  'In 2000 The Simpsons Predicted The Donald Trump Presidency',
#  'Are Dems’ Late-Night Sock Puppets a Sign that the Fairness Doctrine Should be Restored?',
#  'Ben Stokes: England all-rounder loses New Balance sponsorship',
#  'Very Violent Reversal Before End of 2017, N.Korea Thinks US is Bluffing – James Rickards, Greg Hunter Video',
#  'New Documents Show Pentagon Is Shipping Billions Worth Of Weapons To Terrorists In Syria, Trying To Cover Its Tracks',
#  'Mom Puts Glasses on Her Baby – Watch Her Face As She Sees Her Dad for the First Time',
#  'Bizarre Things That Just Don’t Make Sense About the Las Vegas Mass Shooting False Flag Event; Bizarre Things That Just Don’t Make Sense About The Las Vegas Mass Shooting False Flag Event',
#  'A ‘Dynasty’ for Generation ‘Gossip Girl’ (Mom Can Watch, Too)',
#  'Disney, Hillary Clinton and the Obamas Condemn Weinstein',
#  'MacArthur Foundation Fellows: Winners List',
#  'Safeway Open: Brendan Steele wins title for second year in succession',
#  'Lawrence Thomas Officially Makes Switch to Fullback',
#  'CNN Hero Mona Patel: Sparkle Twins',
#  'Las Vegas Shooting Makes Country Guitarist Change His Mind On Guns',
#  'Netflix fends off criticism over Canada investment',
#  'Huge Triangle Shadow In The Sky In Louisiana',
#  'Kenyan Election Officials Open New Vote to All Original Candidates',
#  'Some Tips for Selecting The Best Flower Bouquet Online',
#  '12 Rohingya refugees killed after boat capsizes between Myanmar and Bangladesh',
#  'Nelly arrested on suspicion of rape',
#  'Happy 350,000th birthday: Study pushes back Homo sapiens origins',
#  'Kids & Fitness....Get the Kids Off the Couch & Have Some Fun!',
#  "Exclusive: EU regulators set to approve Atlantia's bid for Abertis - sources",
#  'France still not confirmed IS links to Marseille attacker',
#  "North Korea's Other Threat: Why EMP Becomes An Extinction Level Event",
#  'Where Is President Trump’s Sense Of Compassion?',
#  'New Documents Show Pentagon Is Shipping Billions Worth Of Weapons To Terrorists In Syria, Trying To Cover Its Tracks',
#  'Jimmy Kimmel Weeps As He Talks About Shooting In His Hometown',
#  'Wonder Woman’s Surprising Back Story Has a Film of Its Own',
#  'Mom Fights Back Home Invaders On Detroit’s West Side',
#  'Gatekeeper Invades The 312 Podcastto Preview the Blackhawks Season',
#  "'Dancing With the Stars' Las Vegas tribute",
#  'Can You be Hacked by the World Around You?',
#  "10/5 TRS-PNC Park: Bucs Win in '71, '79; Lose Four Playoffs (Dang Reds!); Tracy Fired",
#  'U.S. insured wind, storm surge loss from Hurricane Nate around $500 million: KCC',
#  "The online bots behind Vladimir Putin's birthday wishes",
#  'Rose McGowan Attacks Ben Affleck Over Harvey Weinstein: ‘You Lie’',
#  "Mexico warns U.S. against 'protectionist war,' peso weakens",
#  "Weinstein and the media's shame",
#  'Broken2th And Crystal Sun Release "Castaliah"',
#  'Audio Released of Hotel Worker Warning of Shooter BEFORE Vegas Massacre',
#  'A Look at the Thursday Night Football Games',
#  'The rising profile of football in Australia',
#  'Women Absorb And Retain DNA From Every Man They Have Sex With',
#  'U.S. House approves disaster funds as Trump criticizes Puerto Rico',
#  'Elliott again ups Hitachi Kokusai stake, KKR raises offer price',
#  'Cowboys WR Dez Bryant - Team Done with Anthem Demonstations',
#  'FSU Opponent Preview: Wake Forest',
#  'Ancient Papyrus Scroll Reveals How The Egyptian Pyramids Were Built',
#  'Colbert: Dinosaurs knew better than Weinstein',
#  '20 holiday destinations the experts say not to miss',
#  'Fed Still Puzzled by Inflation, but Rate Increase Is on Track',
#  'Nobel Prize in medicine: US body clock scientists win',
#  '2017 NLDS: Will Max Scherzer miss Game 1?',
#  'Trump Poised to Sign Order Opening New Paths to Health Insurance',
#  'The Shocking Carol Woods Coverup: POLICE ALTER RECORDS + archive 11 Sept. 2017',
#  "Highlights of Sunday's MLB playoff games",
#  'Is 16th-century charcoal sketch a naked Mona Lisa?',
#  'Tailgate - Jaguars vs Jets',
#  'Hero who saved 30 people reunited with officer who saved his own life',
#  '2017 Get ‘em or Don’t Sweat ‘em - Week 4',
#  'Pakistan v Sri Lanka: Tourists win second Test by 68 runs to take series 2-0',
#  'Trump Administration Urges Congress To Renew Foreign Intelligence Surveillance Act (FISA)',
#  'John Elway Says That It’s Time to Take the Politics OUT of Football',
#  'Theresa May needs to resign for the good of Britain',
#  'Employers Can Now Refuse to Pay for Birth Control, Thanks To Trump',
#  'Teacher Told Students They Were ‘Too Dark-Skinned’ To Play Lincoln',
#  'Strange Object Spotted Over Newfoundland, Canada',
#  'Exclusive: Priorities USA runs tax reform TV ad',
#  'Secrets of the Super Elements',
#  "Kaspersky's U.S. spat a sign of Balkanisation in cyber world: Interpol",
#  'Rohingya crisis: Finding out the truth about Arsa militants',
#  'Wall Street Vs. Kremlin: Who Really Runs The White House?',
#  'How serious is Trump on DACA?',
#  'Rich Would Benefit Most From Trump Tax Cut Plan: Policy Group',
#  'Hungary’s “Wall” Versus the U.S. “Wall”',
#  'Ray Says He Was Praying, Not Protesting',
#  'Trump resists pressure to soften stance on Iran nuclear deal',
#  'Stolen baby photos, albums returned to mom years later',
#  'Highlights: Hong Kong leader Carrie Lam delivers maiden policy address',
#  'Kneeling For The National Anthem Isn’t Disrespectful, It’s Patriotic',
#  'Diary of Anne Frank transformed into graphic adaptation',
#  'The ‘Sweet Season’ in Coming Up, But with Good Habits and Careful Monitoring, Teeth Problems can be Avoided, According to Gilroy Dentist',
#  'War on Cash Backfires on India’s Economy',
#  'Trump Threatens WW3 "Reviewing Plans To Send Weapons To Ukraine"',
#  'This High School Is Threatening To Ban Players Who Kneel During Anthem',
#  "China's COMAC says C919's third test flight delayed due to bad weather",
#  'Harvey Weinstein Is Gone. But Hollywood Still Has a Problem.',
#  'Republican Wants Women To Be ‘Traditional Homemakers And Family Wives’',
#  'Harlem hatter brings past to life\u200b',
#  'Trump and Eminem once friendly, not anymore',
#  "'Helicopter Money' Coming Michael Pento",
#  "How we tick: U.S. 'body clock' scientists win Nobel medicine prize",
#  'What a shot! 29 amazing sports photos',
#  '11 Commission Witnesses: The “Minders”',
#  'Drained of cash and riven by rivalries, UNESCO seeks leader to revive fortunes',
#  'Video Released of Elderly German Captive Beheaded by Islamic State',
#  'Review: Money Can’t Buy the New ‘Dynasty’ Excitement',
#  'The Yankees Live To See Another Day!',
#  'Iraq forces retake town of Hawija from IS',
#  '‘Fixed Upper’ Stars Announce Final Season - really',
#  'U.S. to Cut Embassy Staff, warn travelers from Cuba',
#  'Las Vegas: Bombshell Video Shows Second Shooter During Vegas Massacre The Alex Jones Channel',
#  'California Seeks Ban On Fossil Fuel Cars Laying The Groundwork To Ban Humans From The Road',
#  "Las Vegas massacre: How a stranger saved a woman's life",
#  'NFL Malcontent Marshawn Lynch Wears Anti-Trump Shirt to Game',
#  'Blue Martinez',
#  'Trump lays into ESPN anchor suspended over tweets',
#  'Hosting Proms and Selling Cows: North Korean Embassies Scrounge for Cash',
#  "2017 world's best travel photos",
#  "Avid Hunter Don Jr. On Gun Silencers: ‘It's Just A Great Instrument’",
#  '5 Things to Think About',
#  'The Castration Cure',
#  'Noah: Trump should pretend to like Puerto Rico',
#  'Brazilian activist awarded for fight against Amazon rainforest dam',
#  'Streaming Defenses (2016): Week 4: Which Offense Do We Want To Exploit?',
#  'Judge Awards Alleged Rapist With Parental Rights',
#  'Just Shut Up & Play Some Damn Baseball!!',
#  'New Oregon Law will Help Facilitate the Sale of Industrial Hemp Products',
#  "UK tech firm Micro Focus to curb code reviews by 'high risk' governments",
#  'Hangover Win',
#  '50 & The Inspirational Journey Of Aaron Judge',
#  'Quantum Computer in a Nutshell',
#  'Brooke Shields reveals Trump asked her out',
#  '2017 Fantasy Football Kicker Rankings - Week 5',
#  'Coach: Football player convicted of rape earned a 2nd chance',
#  'Police take shot at actor on movie set',
#  'Burnett calls out Clinton over Weinstein',
#  'Come Together',
#  'Game Photos: Michigan at Purdue',
#  'New York Architects Chosen for Major New London Concert Hall',
#  'Plus size model Ashley Graham shames those who troll her workout videos',
#  "Australia's AMP buys U.S. logistics group from Carlyle",
#  "Russia's Putin, eyeing election next year, pledges to prosecute vote violations",
#  'Can Boston Red Sox Recover from Epic Beatdown by Houston Astros?',
#  'Freedom Exists Under Natural Law',
#  'House Republicans Answers ‘Why Does Tax Reform Matter to You?’ in new video',
#  'A Poor Chinese Intern May Have Been Forced To Make Your Branded Laptop',
#  'Trump Fans Are Collecting The Personal Info Of Thousands On The Left',
#  'In John Green’s ‘Turtles All the Way Down,’ a Teenager’s Mind Is at War With Itself',
#  'New York Shake Shack to Test Out Robotic Personnel in Blow to $15 Minimum Wage',
#  'Kyrgios finds purpose in helping underprivileged children',
#  'which teams have already qualified?',
#  'China says hopes Iran nuclear deal stays intact amid Trump criticism',
#  'New Coach Reminds Fans That Purdue Has a Football Team',
#  'China Open: Caroline Garcia beats world number one Simona Halep to take title',
#  '2017 Fantasy Football Quarterback Rankings - Week 5',
#  'For Second Week in row, Jets Youngsters Shine',
#  'Eric Trump National anthem should be kept sacred',
#  'Eric Trump National anthem should be kept sacred',
#  'A Veteran Asks, “What’s Worse, a Kneeling Millionaire or 300,000 Vets Neglected to Death?”',
#  'Hand Feeding Humming Birds – AMAZING!',
#  'Las Vegas Bombshell: Video Appears to Show Muzzle-Flash From 4th Floor, Not 32nd (Video)',
#  "Trump got you down? There's Hope.",
#  'Amazon Rising',
#  "Colbert surprises 'Last Week Tonight' audience",
#  'How a businessman struck a deal with Islamic State to help Assad feed Syrians',
#  "Why Don't You Just Hand The Indians The Trophy, Joe?",
#  'WARNING: Italian SUPERVOLCANO on the brink of ERUPTION',
#  "A transgender midshipman fights Trump's ban",
#  '10/3 TRS-PNC Park Era: Bucs Win a Couple, Lose a Couple Playoff Games; Roberto & Pops Finales & Game Stories',
#  'Catalan leader under pressure to drop independence',
#  "EU says 'ball entirely in UK court' for move to next Brexit talks phase",
#  "'Blade Runner,' 'Westworld' test our empathy",
#  'Vegas Mass Shooter Was Verbally Abusive Towards Girlfriend',
#  'Chicago Cubs accomplish rare franchise feat with NL Central win',
#  'PRESIDENT TRUMP says: Las Vegas shooting - Live updates',
#  'Nowhere to Go but Up?',
#  '10/8: HBD Tom, Donie, Danny, Catfish & Spanky; Hans #2; Cannonball Coming',
#  'Review: Shakespeare Meets Elevator Repair Service. Mayhem Ensues.',
#  'United States miss out on World Cup after Trinidad loss',
#  'Ravens Again Abandon Running Game',
#  'Yankee Burn',
#  'Indians’ Secret Weapon May Be Yan Gomes, Their Catcher From Brazil',
#  'Police Are Looking For These 2 Creepy Masked Figures That Appeared In The Woods',
#  'Bali volcano on brink of eruption for the first time since 50 years, evacuations ordered',
#  'Sold Out: The Underground Economy of Supreme Resellers',
#  'Jacoby Jones to Retire a Raven',
#  'In Cuba, Sourcing Style',
#  "Linklater's war veteran comedy speaks to modern America, says star",
#  'Ravens Lay Another Egg',
#  "Germany's Schaeuble backs ECB plans on bad loans",
#  'Ray Says He Was Praying, Not Protesting',
#  'Trump’s Cabinet Travels In Style At The Expense Of Tax Payers',
#  "After Alleged 'Moron' Remark, Tillerson Strokes Trump's Ego",
#  "Trump on health care: I'll do it myself",
#  'German Foreign Policy Experts Warn Against Anti-Americanism',
#  'California Clothing Store Owner’s Trump as Nazi Billboard Backfires Big Time',
#  'How to Make Money While Playing Video Games Online?',
#  'Mommy Signed Her Up For Preschool. Her ‘Rundown’ Of The Day Has The Internet In Laughter; Mommy Signed Her Up For Preschool. Her ‘Rundown’ Of The Day Has The Internet In Laughter',
#  '9/29 From the 50s Forward: HBD Ken, Teke Takes Two, ALou #2, Browns, 6-In-A-Row, Cutch Walks It Off, Giants Finale',
#  'Spark gene therapy improves vision, at least in short term: FDA',
#  'Financialization and The Destruction of the Real Economy',
#  'U.S. Suspends Visa Services in Turkey, and Turkey Responds in Kind',
#  'At Queens Museum, the Director Is as Political as the Art',
#  'Ravens @ Raiders - Wednesday',
#  'Las Vegas Massacre: Thought Provoking – ‘No Conclusive Evidence or Information About This Shooting’',
#  'SpaceX: BFR Will go from any city to any other city on Earth in under an hour',
#  'Trickle Down Taxation - A.F. Branco',
#  'Trump On Gun Violence: ‘We’re Not Going To Talk About That’',
#  "Portsmouth owner Eisner's journey from Disney to Pompey",
#  'She Was About to Quit Acting. Then She Got the Role of a Lifetime.',
#  'Where Video Game Conventions Draw 300,000: Not in the U.S.',
#  'What will Trump do about the Iran nuclear deal?',
#  'Obama cries seeing Malia off to college',
#  'What a shot! 32 amazing sports photos',
#  'Are These Radiation Detectors?',
#  'Brazil congressional report recommends shelving Temer charges',
#  "10/1 Happenings: HBD Specs, Jim & Vance; Max Swipes 51; O'Connell Deal; Danny Quits & More...",
#  'Trump to visit Puerto Rico on Tuesday',
#  'Neo-Nazi Dennis Mothersbaugh Proudly Wears ‘God, Guns & Trump’ T-Shirt',
#  'Snapchat and Jeff Koons Collaborate on Augmented Reality Art Project',
#  '11 Gave Us the Police State With the "Patriot" Act, After Vegas Get Ready for "USA Liberty" Act',
#  'Can we tell if Donald Trump has a high IQ?',
#  'UN Allegedly Nixed A Report That Predicted The Rohingya Crisis',
#  'Ravens’ Problems Start at the Top',
#  'Top 100 European Innovative Universities Comparison',
#  'Russian football commentator walks out live on air',
#  'Lambeau Field has become a House of Horrors for the Chicago Bears',
#  'Now A Sitcom About An Illegal Family!!!',
#  'A look at four storms from one brutal hurricane season',
#  'Exclusive: Russian-linked group sold merchandise online',
#  "Japanese GP: Lewis Hamilton position 'not comfortable at all'",
#  'Podcast - @Hokiesmash_ASD & @TalkinACCSports talk FBI investigation and ACC football\\network with @AnishESPN',
#  "Judge tosses lawsuit by Jared Fogle's ex-wife against Subway",
#  'The Durham Bulls in 2017 - Part 3 - The Hitters',
#  'PRESIDENT TRUMP says: Las Vegas shooting - Live updates',
#  'Daniel Howell posts YouTube vlog revealing struggles with depression',
#  "Microscope trailblazers win chemistry Nobel for 'freeze framing' life",
#  'Trump tells reporters ‘The Flag Has to be Respected’ [Video]',
#  'Podcast - @Hokiesmash_ASD & @TalkinACCSports talk FBI investigation and ACC football\\network with @AnishESPN',
#  "British Swimming apologises for 'climate of fear' findings",
#  'Dove faces PR disaster over ad that showed black woman turning white',
#  'London No Cup o’ Tea for O-Line',
#  '2 gay Iraqi soldiers found love amid war -- then fled to the US',
#  'Playing With Heavy Heart, Jets’ Ealy Dominates on D-Line',
#  'The flight routines of super-travellers',
#  'The Codex Seraphinianus, Compendium Of An Otherworldly Natural Science',
#  'Where Is The Relief Money For Texas Hurricane Victims? Please Share!',
#  'The “FREE” Press Is NOT Free To Tell The Facts About Vaccines',
#  'GMexico Transportes plans IPO on October 31 -filing',
#  'At Queens Museum, the Director Is as Political as the Art',
#  'Google uncovered Russia-backed ads on YouTube, Gmail : source',
#  '2017 Fantasy Football Running Back Rankings - Week 4',
#  'North Korean ship loaded with 30,000 grenades seized by US en-route to Egypt',
#  'PA Attorney General Concerned About Equifax Cyberattack; Will U.S. Attorneys General Be Upset About Utility Smart Meters Hacking?',
#  'How would you feel about this Blackhawks lineup?',
#  'MacArthur Foundation Names 2017 ‘Genius’ Grant Winners',
#  'Brexit talks deadlock on cash, Barnier eyes move by December',
#  "People we've lost in 2017",
#  'Ah! My kid is having a tantrum, and I want to scream',
#  'Ole Smoky Tennessee Moonshine Becomes A Proud Sponsor Of The Tennessee Titans',
#  'Hollywood reacts to Harvey Weinstein abuse claims',
#  'President Donald Trump’s Schedule for Friday, September 29, 2017',
#  'Fantasy Football; Week 4 Advice',
#  "'Blade Runner,' 'Westworld' test our empathy",
#  "Trump continues NBC threats, says 'licenses must be challenged'",
#  'World Cup 2018: Arjen Robben retires from Netherlands duty after Sweden defeat',
#  '10 Important Stories From 09/24/17 Box Scores: Devers Delivering, Anderson/Giolito Are Regression Risks & More',
#  "Trump: Senate Intel Committee should investigate 'fake news'",
#  '2 Top Officers of Navy Ship John S. McCain Are Removed',
#  "Conway: We're doing what we can in Puerto Rico",
#  'Cam Newton Laughs At Female Reporter Talking About Football',
#  'Active Shooter Reported Near Las Vegas Casino',
#  'SNL Pushes For Gun Control: ‘This Shouldn’t Be a Partisan Issue’',
#  "Are Tillerson's days numbered?",
#  'Ultra-rich family dynasties are bleeding the United States dry',
#  'Diary of Anne Frank transformed into graphic adaptation',
#  'Are the Niners Ready to Turn the Corner? Only Time Will Tell',
#  'Australia Successfully Reformed Gun Laws, Why Can’t The US?',
#  'Ravens vs. Steelers - Thursday',
#  "Apple nears TV deal with Spielberg for 'Amazing Stories'",
#  'Japanese reporter died after clocking 159 hours of overtime',
#  'White House Press Briefing 10/5/17',
#  'The Premier League Show: Why Crystal Palace are perfect for Wilfried Zaha',
#  'How a Foreign Policy of Empire Building Will Destroy the United States',
#  'UFC 216: Tony Ferguson calls out Conor McGregor after winning interim lightweight title',
#  'If The Yanks Do These Things, They Can Beat The Tribe!',
#  'The graphic design that can help save lives',
#  "Saudi King issues decree: 'Women now allowed to drive cars'",
#  'Ray Says He Was Praying, Not Protesting',
#  'Facing the Stigma of Diabetes',
#  'Donald Trump is acting like a fifth-grade bully',
#  'U.S. heating costs forecast to be higher this winter: EIA',
#  'Start ‘Em or Sit ‘Em (2017): Week 4: Dak Prescott, Chris Carson, T.Y. Hilton & More',
#  "Brazil police say JBS owners 'profited' from inside information",
#  'Political point scoring muddies sexual-harassment coverage',
#  "U.S. trio win Nobel for finding Einstein's gravitational waves",
#  "In Trump's America, White Families 10 Times Wealthier Than Black Ones",
#  'Video Shows Utah Cop Fatally Shooting Black Man From Behind',
#  'Have you ever seen a miss worse than this?',
#  'Danish Minister Republishes Controversial Prophet Cartoon',
#  'Teacher Told Students They Were ‘Too Dark-Skinned’ To Play Lincoln',
#  'Puerto Rican Police Officer: San Juan Mayor not allowing distribution of aid supplies',
#  'Ravens vs. Steelers - Wednesday',
#  'Blue Ribbon Preseason Top 25 Includes Six From ACC',
#  '10/3 Expo Park-Forbes Field Era: Pirates, Grays WS Win, Game Stories',
#  'How to help victims of the California wildfires',
#  "The full lyrics to Eminem's Trump-bashing freestyle 'The Storm'",
#  'Jeet Feels The Heat',
#  "Russia protests to U.S. 'shameful' theft of consulate flags",
#  "'SNL' returns with Trump mockery",
#  "Barcelona's African street traders swap crime for craft",
#  "In Trump's America, White Families 10 Times Wealthier Than Black Ones",
#  'Srebrenica defender Naser Oric cleared of war crimes in Sarajevo',
#  'Xi Jinping Presses Military Overhaul, and Two Generals Disappear',
#  'Cam Newton Laughs At Female Reporter Talking About Football',
#  'Will Security Measures Change In Response To Mass Shootings?',
#  'Passing Game Film Review - Good McCown - Week 4 (Jaguars)',
#  'Forte, Leggett Out, Shell Doubtful - Injury Report',
#  "Lord Coe: Athletics must consider 'radical changes', says IAAF president",
#  "Air Force Academy Head To Racists: 'Get Out'",
#  '2017 Fantasy Football: Week 4 Sleepers',
#  'Bloody Luck - A.F. Branco Cartoon',
#  'Steelers Ring the Bell 35 Times in Huge 26-9 Road Win Over the Ravens',
#  'Around the #ACC Blogosphere For September 21, 2017',
#  "Trump To Make 'Important Announcement' On North Korea Today, McMaster Says",
#  'The Real Dreamers are Elite Corporations',
#  'Buy ‘Em or Deny ‘Em: Is Chris Johnson A Worthy Fantasy Option?',
#  '5 Things to Think About',
#  'The Durham Bulls in 2017 - Part 2 - The Pitchers',
#  'What’s on TV Saturday: ‘Spielberg’ and ‘Clueless’',
#  'Trump Is So Busy Bashing NFL, He Forgot To Hire A Science Adviser',
#  'Trends to Watch',
#  'Scorned Alabama Crimson Tide Now on Mission to Destroy NCAA With Extreme Prejudice',
#  'Podcast - @Hokiesmash_ASD & @TalkinACCSports talk FBI investigation and ACC football\\network with @AnishESPN',
#  'Pacific Ring of Fire Waking Up? Major Geological Events Trigger Concerns',
#  "10/4 TRS-PNC Park Era: Reds Thump Buc 3x in Playoffs; Cole Beats Cards; Bucs Clich in '15; Syd, JR Axed;",
#  'Growing Chorus Confronts Trump Against Leaving Nuclear Deal',
#  'SNL Pushes For Gun Control: ‘This Shouldn’t Be a Partisan Issue’',
#  'Trump Mocks Puerto Rico In Hispanic Heritage Speech - It Was Horrible',
#  "North Korea: Trump has 'lit the wick' of war",
#  'Woman Throws Drink On Lakers Fans Who Took A Knee During The Anthem',
#  'On SNL, Alec Baldwin’s Trump Calls San Juan Mayor “Nasty Woman”',
#  'Miley Cyrus tears up thanking Hillary Clinton',
#  "Austria's Islamophobic 'Burqa Ban' Criminalizes Muslim Women",
#  "10/1 TRS-PNC Era: Wildcard Win, TRS Closes, Freddy Takes Crown, Locke's 1st Win & More",
#  'Bucs Take It To Last Strike In 4-1, Never-Say-Die Win',
#  'Equifax Hack: Is this how they roll out the Implantable RFID Chip to every person in USA or World?',
#  'Chicago Bears receiving core struggling early on',
#  'Restructures for Several Veterans',
#  '5 Of The WORST Plastic Surgeries You Have Ever Seen!',
#  'The best former professional athlete to run a sports team',
#  'Bullpen Notes: September 25, 2017: Barraclough Gets Save, Familia’s Outlook & More',
#  'Rising Rock ‘n’ Roll Band Dynamos Unleash their Lead Single: “Shake, Rattle and Roll,” Available 10/13/17!',
#  'Smart Billboards Target Individual Motorists and Spy on License Plates and Cellphones',
#  'New York Cable provider Altice will have the ACC Network',
#  'Yankees Take American League Wild-Card Game, Will Face Cleveland Indians Next',
#  'SECRET Document Reveals Former CIA Director’s Plan to Make Reading WikiLeaks a Crime',
#  "9/30 TRS-PNC Era: 3,000 For Roberto, '79 Clincher, HBD Bryan, Cover Boy Scoops, Game Stories",
#  "They'll wash the blood away, but won't forget",
#  "9/25 Happenings: Bucs Clinch in '60; NH GM; HBD Dave, Dick, Tony & Vanimal; Wilson, Williams Records,",
#  'Tropical Storm Ophelia forms over the open Atlantic',
#  "9/30 Expo Park-Forbes Field Era: Temple Cup, '08 Race, Mo Bros, Kiner Wallops, Herman Deal, K Mart",
#  'Tubby Boy X Telboy - Oh So Real (Out Now)',
#  'Cubs Open Title Defense With a One-Two Punch From Bryant and Rizzo',
#  'Around the #ACC Blogosphere For September 21, 2017',
#  'Stars give their tips on getting your music heard',
#  'Brazil wants $12.7 billion fine on Andrade engineering firm: O Globo',
#  '50 & The Inspirational Journey Of Aaron Judge',
#  "Head of Brazil's central bank defends bank bail-out bill",
#  'House passes GOP budget in key step for upcoming tax debate',
#  "10/1 TRS-PNC Era: Wildcard Win, TRS Closes, Freddy Takes Crown, Locke's 1st Win & More",
#  'Secrets of the Super Elements',
#  'Raiders Throw Game to Punish QB Who Wouldn’t Protest Trump - Where Is Roger Goodell Now?',
#  'In Pennsylvania, Trump Hunts for Democratic Support for Tax Plan',
#  'Is The Tech Industry Fighting White Supremacy Or Fueling It?',
#  'Food Truck Giving Free Food to Hurricane Workers, Kicked Out of Town for Not Having a Permit',
#  "'Heroin heroine' saves lives from her living room",
#  'Australia dual citizenship saga: Court hearing begins',
#  'Oh, rats! Big tree-dwelling rodent found in Solomon Islands',
#  'What the UK and Australia did differently after mass shootings',
#  'Company Scrambles as Weinstein Takes Leave and a Third of the Board Resigns',
#  'What a shot! 29 amazing sports photos',
#  'Jets Release Tight End Will Tye, Practice Squad RB Marcus Murphy',
#  'Donald Trump: Has US debt fallen since the president took office?',
#  'Portraits of the Las Vegas shooting victims',
#  'Dove Ad Shows Black Woman Miraculously Transform Into A White Woman',
#  'Top 100 European Innovative Universities Methodology',
#  'Allows Local Common Core Opt Out',
#  'Senators Eviscerate Wells Fargo CEO Over Fake Accounts Scam',
#  'CNN Hero Mona Patel',
#  '10/7: Chuck Axed; HBD Brickyard, Adam, Moonlight Ace & Chuck; AS; Season Finales...',
#  'NFL Marketing Machine',
#  'Can We Survive Technology? The Origin of SRM Geoengineering and the Modern Theory of Man-made Global Warming',
#  'Meet The Racist GOP Candidate On A ‘Special Assignment’ From Trump',
#  'Brazil wants $12.7 billion fine on Andrade engineering firm: O Globo',
#  'The Ditch List: Is It To Cut These Three Struggling Running Backs',
#  "'SNL' returns with Trump mockery",
#  'How N.F.L. Overtime Works',
#  'Trump Goes After Senator Bob Corker, Who Bites Back',
#  'PRESIDENT TRUMP says: Las Vegas shooting - Live updates',
#  'Robin Thede: A Black Woman Hosting Late Night? That’s No Joke',
#  'Tropical Storm Nate could strike US Gulf Coast as hurricane this weekend',
#  "Villagers in India's Rajasthan reclaim common land with maps, petitions",
#  'Liberia’s Women Warn Male Presidential Candidates: Keep the Peace',
#  'Chicago Bears receiving core struggling early on',
#  'Catalan independence push puts Spanish border town on edge',
#  'Exclusive: Despite sanctions, Russian organizations acquire Microsoft software',
#  'FEMA Is a Front for a Depop Program? - FEMA Ships; Reports From After AI Hurricane Harvey (Video)',
#  'Trump’s Failed Golf Course Cost Puerto Rican Taxpayers $33 Million',
#  'Questions to Ask if You Still Believe the Official Narrative',
#  'Week 5 Rankings (2017): Top 25 Quarterbacks: Newton/Wilson Return To Top 5 & More',
#  'Social Experiment Show Police Is Rife With Racism',
#  'Disney’s Big Bet on Streaming Relies on Little-Known Tech Company',
#  'from heart attack to further hockey history?',
#  "290 arrests in anti-Putin march on Russian leader's birthday",
#  'Vendange Carmel Inn and Suites Announces New Wine-Themed Room in Partnership With Award-Winning Soledad-Based Carmel Road Winery',
#  'What CST Thinks about Bengals-Browns today',
#  'Rising Rock ‘n’ Roll Band Dynamos Unleash their Lead Single: “Shake, Rattle and Roll,” Available 10/13/17!',
#  'Puig Powers Dodgers to 8-5 Win Over D-Backs, 2-0 Series Lead',
#  "Are white shooters called 'lone wolves,' by default?",
#  'Americans for Prosperity Pressures Dems to Support Tax Reform with New Ad',
#  '2017 Fantasy Football IDP Rankings - Week 5',
#  '9/28 Through the 40s: The Gloaming; HBD Bill, Lou, Cy the Third, Everett, Cy, Leon & Buck; Clarke Honored;Tiny 2-Hitter',
#  'Facebook confirms Russia ads on Instagram',
#  "Interior secretary's trips may have violated law",
#  'Missing Link Music Signs Bluegrass Songwriter Of The Year Daryl Mosley',
#  'Democrats under pressure to disavow Weinstein',
#  'Hamlet, Lear line the Thames in London Shakespeare celebrations',
#  'Ian McKinley: Fly-half named in Italy squad after losing sight in 2012',
#  'This Is An American Warning, We Are Headed For Rough Times David Robertson',
#  'Week 4 Rankings (2017): Top 50 Wide Receivers',
#  'Russians, Heeding Navalny’s Call, Mark Putin’s Birthday With Protest',
#  'It Begins: Feds Demand Facebook Hand Over Info on Anti-Trump Users',
#  'Non-Lethal? Police Tasers Have Killed Over 1,000-Many With Mental Health Problems',
#  "O.J.'s lawyer: I've never heard him so upbeat",
#  'GOTW: Preston v Sunderland',
#  'Goodell and N.F.L. Owners Break From Players on Anthem Kneeling Fight',
#  "For Algeria's struggling herders, drought stops everything",
#  'Hundreds Injured As Police Shut Down Catalan Vote',
#  'Teen Suspended For Sitting During Pledge Of Allegiance',
#  'SNL: Michael Che Calls Trump “You B*tch” Over Puerto Rico Response',
#  'Friday: Pirates at Nats, Cole v Strasburg, Lineup, Notes',
#  "Roger D'Arcy Releases New Album 'House Of Heads'",
#  'Las Vegas Shooting Mandalay Bay Was Staged ~ Fake Actors (Proof); Las Vegas Shooting Mandalay Bay Was Staged ~ Fake Actors (Proof)',
#  'Mother Accused Of Killing Newborn And Living With The Dead Baby’s Body For 3 Months',
#  'Republicans Open to Banning ‘Bump Stocks’ Used in Massacre',
#  'Why Arpaio pardon still rankles',
#  'Will Security Measures Change In Response To Mass Shootings?',
#  'Carmen Cruz, Mayor of San Juan Is A “Godsend” For Puerto Ricans',
#  'Rex Tillerson: Secretary of State insists he never wanted to quit',
#  'Red Lobster Customer Makes Bomb Joke to Hostess, Guess What She Brings Him',
#  'Germany registers fewer asylum seekers, on track for annual cap',
#  'Are you drinking enough water to be healthy?',
#  'Exclusive: U.S. warship sails near islands Beijing claims in South China Sea - U.S. officials',
#  "U.S. Based Charity Is Robbing Mexico's Indigenous Communities of Water",
#  'If The Yanks Do These Things, They Can Beat The Tribe!',
#  'Maria Sharapova reaches Tianjin Open quarter-finals by beating Magda Linette',
#  'Trump Is So Busy Bashing NFL, He Forgot To Hire A Science Adviser',
#  'Amazing F-16 Night Takeoff',
#  'Russia Accuses US Of Sabotaging Liberation of Deir ez-Zor',
#  'With iPhone’s New FaceID, Cops Can Unlock Your Phone by Pointing at Your Face-While You’re Cuffed',
#  'Pre-Order The Rotoprofessor 2018 Fantasy Baseball Draft Guide For $6.25!',
#  'Pre-Order The Rotoprofessor 2018 Fantasy Baseball Draft Guide For $6.25!',
#  'Brazil police arrest Olympic committee chief in vote-buying scandal',
#  'Buy ‘Em or Deny ‘Em: Is Now The Time To Move On From Mike Gilislee?',
#  'Thursday Night Start ‘Em or Sit ‘Em: Week 4: Randall Cobb, Jordan Howard, Tarik Cohen & More',
#  'Japan and Utility Are Found Negligent Again in Fukushima Meltdowns',
#  'Financialization and The Destruction of the Real Economy',
#  'President Trump and The First Lady Lead a Moment of Silence for Las Vegas',
#  'This Abandoned Village Shows What Would Happen If Human’s Didn’t Exist, It’s Hauntingly Beautiful',
#  'Doesn’t Pay to be Ordinary on Defense',
#  'Monday Morning Thoughts; Jets Top Jaguars',
#  '2017 Fantasy Football Wide Receiver Rankings - Week 4',
#  'U.S. small-cap firms look to spend tax savings on tech, not jobs',
#  'Pope to get closer to heavens with call to space station',
#  'Relaxing into the Original Style of Karate',
#  'Schumer Says He Rebuffed Another Offer From Trump on Health Care',
#  'Louisville’s first move should be to let go of Rick Pitino.',
#  'What CST Thinks about Bengals-Browns today',
#  'Producer Harvey Weinstein suspended from British film academy',
#  'US climber kills himself after avalanche kills girlfriend',
#  'Coaching Staff Failing Ravens',
#  'North Korea crisis: US bombers conduct military drills',
#  'Egypt Qualifies For World Cup In 27 Years Amidst Political Instability',
#  "Indian child brides sold in 'package deals' to men from Gulf states",
#  "Box Office: 'Blade Runner 2049' fades to $31.5 million opening weekend",
#  'PreseasonBlackhawks at Boston4-2 Loss Recap',
#  'Zak Hardaker: Castleford Tigers full-back banned after positive drugs test',
#  "Japanese lottery winners get 'collectable' manhole covers",
#  'High Ranking CIA Agent Blows Whistle On The Deep State And Shadow Government',
#  'Florida State’s season is in a heap of trouble.',
#  "One of Liberia's main parties calls for halt to election results",
#  'Schooled in Scandal: What Makes Ukraine a Hotbed of Intrigue',
#  'Miami Dolphins Kneelers Crap All Over America on Foreign Soil in London NFL Game',
#  "'Brexit not a game,' EU's Barnier says",
#  'Robert Plant, Party of One. (With Friends, Too.)',
#  'Ten people charged for Louisiana State University hazing death',
#  'Las Vegas American PSYOP: FBI ISIS Connection Final Conclusions by Jim Stone, Freelance Reporter (Video)',
#  'What Happened in Vegas Will Not Stay in Vegas… 16 Questions Left Unanswered That the Media Ignores!',
#  'Washington Post Fails To Cover Amazon Nearly $300 Million Dollar Fine For Tax Dodging',
#  "Trump's generals are speaking up",
#  "Yosemite park rock fall: Tributes to 'hero' climber",
#  'New York Cable provider Altice will have the ACC Network',
#  'Antonio Brown Tweets Out Apology for ‘Noise’ and ‘DIstractions’',
#  'Passing Game Film Review - Good McCown - Week 4 (Jaguars)',
#  'Week 4 Prediction Article - Oakland Raiders @ Denver Broncos',
#  'Chinese Police Orders Uyghur Muslims To Hand In The Holy Quran',
#  "10/5 Expo Park-Forbes Field: Bucs Win '60 Opener, Lose '27; Pud's 300; HBD Claude, Felix & Sarge; Grays Win WS",
#  "10/8 Post-Season: WS Wins in '09, '25, Losses in '03, '27, '60; 1-of-3 in Playoffs",
#  'NFL Fans Are Setting Fire To Their Jerseys In Response To #TakeAKnee',
#  "Japan's Dentsu gets only small fine for overtime breaches despite outcry",
#  'British novelist Ishiguro wins Nobel Literature Prize',
#  "An Object Like Nothing We've Seen Before Has Been Spotted In Our Solar System",
#  'Thursday: Pirates at Nats, Nova v Edwin Jackson, Lineup, Notes',
#  'Cubs Win! Survive Fire-Throwing Strasburg to Grab 1-0 NLDS Lead',
#  "France's CGT calls another strike against labor reform, others refuse",
#  'Barbuda after the hurricane: Residents return to pick up pieces',
#  'Video Shows Utah Cop Fatally Shooting Black Man From Behind',
#  'Spanish stocks rebound in flat European market as Catalonia fears ease',
#  'Donna Karan Wonders if Women Are Dressing for ‘Trouble’',
#  "10/1 TRS-PNC Era: Wildcard Win, TRS Closes, Freddy Takes Crown, Locke's 1st Win & More",
#  'Two historians claim the Ancient Egyptians did NOT build the Pyramids',
#  'Marseille attacker probably radicalized by brother: police',
#  'Australian Cybersecurity Report Shows Gaps in Private Companies’ Defenses',
#  '100 Women: Meet Susi Pudjiastuti, the Indonesian minister blowing up boats',
#  'Huge Gas Explosion Sends Giant Fireball In Ghana’s Capital',
#  'Review: Dead Again … and Again in ‘Happy Death Day’',
#  'GM aims to lead electric vehicles market in Mercosur: executive',
#  'Two Russian tycoons sell 3 percent of aluminum giant Rusal for $315 million',
#  'Sen. Rubio: Remove communist US soldier from officer ranks',
#  "India: What happened to Modi's promise of an economic boom?",
#  'Amazon and Apple caught in latest EU tax crackdown',
#  'Bloody Luck - A.F. Branco Cartoon',
#  'Black Nova Scotians may finally get title to their land',
#  'Melania And Donald Think The White House Is Like A Jail',
#  '7 Truly Terrible Things The Agency Has Done In 70 Years',
#  'British author Rowling says Trump has a right to be bigoted',
#  'Trump Is Preparing to Kill Kim Jong-un - Oh My God! Breaking News TV',
#  'What is the Perfect Golf Swing?',
#  "Trump Isn't Rushing To Save Puerto Ricans Because They Aren't White",
#  'Smart Meter Data: Privacy and Cybersecurity',
#  "Frontline examines 'North Korea's Deadly Dictator'",
#  'Political point scoring muddies sexual-harassment coverage',
#  'China congress: Military facelift a sign of bigger changes',
#  'Yankees Have New Weapons For Postseason Run',
#  'If You’re Italian, German or Irish-American, This is How Your Ancestors Were Treated as Immigrants',
#  '34 Yards',
#  'White House Makes Hard-Line Demands for Any ‘Dreamers’ Deal',
#  'Review: A ‘Show-Off’ Who Doesn’t Know When to Shut Up',
#  "America's Willful Negligence Concerning the 9",
#  "Mexico's Pemex gains two new partners for onshore tie-ups",
#  'Lions Rookie LB Jarrad Davis on the Practice Field After Missing Week Three',
#  'The Chicago Bears versus the Green Bay Packers Quick Injury Analysis',
#  'Gun control: So far, just words',
#  '‘Revenge Was Sweet’: Trinidad and Tobago Exults in Soccer Victory Over U.S.',
#  '2017 Fantasy Football Kicker Rankings - Week 5',
#  'Avoiding Another Debacle',
#  'Biden: US walking down a dark path',
#  "Canada's Magna joins BMW-Intel self-driving car project",
#  "10/4 Expo Park-Forbes Field Era: '08 To the Wire; HBD Jim, Red, Joe & Billy; 103 Wins in '02; Running Into Trouble",
#  'Las Vegas Mass Shooting: False Flag, PSYOP and Black Op to Distract; Deep State is getting very desperate',
#  'Brazil police arrest Olympic committee chief in vote-buying scandal',
#  'Sometimes You Need To Send A Message',
#  'Catalonia: Carles Puigdemont criticizes Spanish King',
#  'Facebook pushes ad overhaul before 2018 U.S. election: executive',
#  'Tournament Time',
#  '8-Year-Old Hammered To Death While Protecting Sister From Molester',
#  'Maverick state governor takes aim at Mexican presidency',
#  '2017 Fantasy Football: Week 5 Sleepers',
#  'Las Vegas Sacrifice: The Incredible Back Story Designed to Cover up the Shocking Truth!; Why Patsy Stephen Paddock Was Set Up To Be A Mass Murderer',
#  "10/2 Games: Bucs Clinch In '74, Boston Evens WS, Goose & Teke at 72, Triple-Bill, Game Stories",
#  'Cam Newton Laughs At Female Reporter Talking About Football',
#  'Trump Tells Pence to Leave N.F.L. Game as Players Kneel During Anthem',
#  'The 2016 Winner Of The Award For Reverse Excellence',
#  'Air France A380 With Engine Damage Makes Emergency Landing VIDEO',
#  'NBC Doubles Down on Tillerson Quitting report',
#  'U.S.-Puerto Rico Basketball Game to Be Moved Because of Hurricane Damage',
#  'A Major Defeat For The New World Order.',
#  "Egypt's Cheiron wins tie-up with Pemex for Mexican onshore oil field",
#  'President Trump, First Lady Receive Briefing on Maria Relief Effort [Live Stream]',
#  'McCain Wrong (again): Jones Act Suspension Won’t Help Puerto Rico',
#  'Theresa May speech marred by prankster Lee Nelson',
#  'Your everyday talks are intended to enable you to get to know one another',
#  "9/30 TRS-PNC Era: 3,000 For Roberto, '79 Clincher, HBD Bryan, Cover Boy Scoops, Game Stories",
#  'Republican Wants Women To Be ‘Traditional Homemakers And Family Wives’',
#  'Louisville’s first move should be to let go of Rick Pitino.',
#  '10 Important Stories From 09/29/17 Box Scores: Story’s Turn Around, Not Buying C. Anderson & More',
#  'Billie Jean King: Emma Stone and Steve Carell star in film',
#  'Puerto Rico Hoax (Video)',
#  "France's Engie to look closely at Brazil Eletrobras assets",
#  'With No Carr, Ravens D Could Feast',
#  'Debbie McGee makes Strictly Come Dancing boo-boo',
#  'Trump’s Visit To Puerto Rico Was A Disaster Of Epic Proportions',
#  'Non-Lethal? Police Tasers Have Killed Over 1,000-Many With Mental Health Problems',
#  'Italy culls birds after five H5N8 avian flu outbreaks in October',
#  'Entire Volume of CIA Files On Lee Harvey Oswald, Set to Be Released in October, Has "Gone Missing"',
#  "Germany's DEA Deutsche Erdoel wins onshore Pemex tie-up in Mexico",
#  'Asia Pacific’s Most Innovative Universities - 2017',
#  'The week in 35 photos',
#  "Voting flap hits New Zealand's Bird of the Year poll",
#  'Cam Newton: NFL quarterback makes sexist comment to female reporter',
#  'Japan to propose changes to beef import safeguards in talks with U.S.: sources',
#  'Report: Low morale on ship monitoring N. Korea',
#  'Week 5 Rankings (2017): Top 20 Tight Ends',
#  "10/8 Post-Season: WS Wins in '09, '25, Losses in '03, '27, '60; 1-of-3 in Playoffs",
#  'George Michael regretted going to war with Sony',
#  'Sen. Collins Says ‘No’ to Graham-Cassidy Healthcare Bill Effectively Killing Effort',
#  'China Open: Nadal beats Kyrgios to take sixth title of the season',
#  '3 US military service members killed in Niger',
#  'Dove Ad Shows Black Woman Miraculously Transform Into A White Woman',
#  'Is Trump Weighing Profit Over The Lives Of 3.5 Million Puerto Ricans?',
#  'Harvey Weinstein sacked after sexual harassment claims',
#  "10/1 Expo Park-Forbes Field Era: Deacon Whips Cy In 1st WS Game, Waner's 237 Hits, Boss Man Roberto & More",
#  'Thai air safety upgrade opens up growing China, Korea, Japan markets',
#  "Like May's speech, my country is a joke",
#  'With No Carr, Ravens D Could Feast',
#  'Ravens vs. Steelers - Friday/Game Status',
#  "Jason Aldean opens 'SNL' with Vegas tribute",
#  'Raiders Throw Game to Punish QB Who Wouldn’t Protest Trump - Where Is Roger Goodell Now?',
#  'Listen to Our Exclusive Interview with Senator Bob Corker',
#  "Carter Page: I'll plead Fifth to Senate Russia probe",
#  'The "Internet of Things" Is Sending Us Back To The Middle Ages',
#  'What a shot! 30 amazing sports photos',
#  'Black model who appeared in Dove ad says it was not racist',
#  'Kate Beckinsale joins Harvey Weinstein accusers',
#  'Trickle Down Taxation - A.F. Branco',
#  'Region for both Online and Land based Gaming',
#  'Matteo Manassero Takes a Mature Approach',
#  'Week 4 Rankings (2017): Top 40 Running Backs: New Names Emerging As Viable Options',
#  'Japan To Build A Space Elevator By 2050',
#  'Kobe Steel crisis deepens as more data tampering revealed; shares tumble',
#  'Progressive Mayor of San Juan Turns Recovery Effort Political',
#  "Trump Isn't Rushing To Save Puerto Ricans Because They Aren't White",
#  '9th inning: 8-10',
#  'OPEC considers second meeting with U.S. independent oil firms',
#  'Ravens @ Raiders - Wednesday',
#  'Search ends for bodies in Mexico City after earthquake',
#  'Turkish court remands German journalist in custody over terrorism charges',
#  "State Department denies Tillerson called Trump a 'moron'",
#  "'Ball in your court:' Britain, EU clash over next Brexit move",
#  'Nelly arrested after allegations of sexual assault',
#  "10 of Asia's highest bars: Where drinks, skyscapers meet",
#  'Terrorism victims seek Supreme Court blessing to sue corporations',
#  'To tackle or not to tackle?',
#  'Democrats and Media Try to Turn Puerto Rico into Trump’s Katrina',
#  'The Chicago Bears versus the Minnesota Vikings In-Depth Game Preview',
#  'Post-Game Recap: Jets beat Jaguars in OT, 23-20',
#  'Anonymous: Las Vegas What Happens There Stays With The CIA (Video)',
#  'Meet The Racist GOP Candidate On A ‘Special Assignment’ From Trump',
#  'Paul Anka Brings Vegas to Englewood, N.J.',
#  "How Cubans have restored America's classic car legacy",
#  'Honeywell seeks M&A as it keeps aero, spins off two units',
#  'Betting on CS GO With Bitcoin',
#  'Nelly Arrested Following Tour-Bus Rape Accusation',
#  "What counts as 'cheating' in the digital age?",
#  'Why can mornings be so difficult?',
#  'Nelly arrested after allegations of sexual assault',
#  'Caspar McCloud Releases First Acoustic Worship Album "Pictures Of Jesus"',
#  '2017 Fantasy Football IDP Rankings - Week 4',
#  'Hollywood mostly silent on Weinstein allegations',
#  'A Staten Island Sensation',
#  'ECB still concerned about existing stock of bank bad loans: Mersch',
#  "Iceland's 'unicorn' goes under the hammer",
#  'The ‘Resistance,’ Raising Big Money, Upends Liberal Politics',
#  'No Congo election until mid-2019, vote commission says, angering opposition',
#  'Man To Howard University Students: ‘It’s Not Murder If They’re Black’',
#  "CW's 'Dynasty' will be about more than catfights",
#  'Syria - What Happens Next?',
#  'Erdogan launches new tirade against US as relations sour',
#  'Yankee Burn',
#  "Rae Morris: 'I gave Zane Lowe a blank CD'",
#  "'Mr. Robot' Season 3 returns to feverish form",
#  'They Tried to Block This Video: Here is What Happened As It Happened! Stunning, Compelling Eyewitness Account Included (Videos); THEY TRIED BLOCKING THIS VIDEO AND WHAT REALLY HAPPENED DURING LAS VEGAS SHOOTING, OCTOBER 2 2017!; LATEST Shooting in Las Vegas – New EYE Witness & What Pres Trump Speech Had to Say – News Worldly; Woman tells Las Vegas concert crowd “You are all going to die tonight.”; Bombshell! The Coming COG Movement: Las Vegas Massacre Is Just The Beginning – Who’s Really Behind It (Video) click here; Updates: Sirens, Gunfire and Screams Rock Las Vegas as Deadly Shooting Unfolds Over 58 Dead! Who the Gunman Is (Videos) click here',
#  'US should hold China accountable on human rights',
#  "Australia's team bus hit by rock in India after T20 win",
#  "9/30 Expo Park-Forbes Field Era: Temple Cup, '08 Race, Mo Bros, Kiner Wallops, Herman Deal, K Mart",
#  'CNN Hero Mona Patel: Sparkle Twins',
#  'Suburban Symphony Release Debut Single "Stepping Stones" On Hilltown Records',
#  'Gov’t Ruined 653,249 Lives Over Cannabis in 2016 Because 5 Corrupt Industries Paid Them To',
#  'Virginia’s hammering of Boise State changes outlook for the season.',
#  'Company Man: Patriots Quarterback Tom Brady Turns on President Trump',
#  'Air France A380 With Engine Damage Makes Emergency Landing VIDEO',
#  'Can we tell if Donald Trump has a high IQ?',
#  'Blackhawks Roster Breakdown: Forwards',
#  'Kim Wall: Divers find head, legs of missing journalist',
#  "10/4 TRS-PNC Park Era: Reds Thump Buc 3x in Playoffs; Cole Beats Cards; Bucs Clich in '15; Syd, JR Axed;",
#  "A congressman's unbearable hypocrisy on abortion",
# ...
#  'Non-Lethal? Police Tasers Have Killed Over 1,000-Many With Mental Health Problems',
#  'Smart Meter Data: Privacy and Cybersecurity',
#  "Facebook and Twitter face a 'bully tax' in Britain",
#  '5 Stages of Grief: London Caw-ing',
#  "Watchdog approves PGE's purchase of EDF's Polish assets, sets conditions",
#  'Week 4 Rankings (2017): Top 25 Quarterbacks: Top 10 Surprises & More',
#  'EPA rolls back carbon emissions rule',
#  "9/28 From the 50s Forward: '52 Woes, Freak SHow Finale, Homer Show, Homer No-No, Game Stories & Stuff",
#  'Trinidad and Tobago 2-1 USA',
#  'Longest War in US History Turns 16 Today',
#  'Ahead of Schedule, Yankees Push Toward World Series',
#  "Cam Newton Says It's 'Funny' Hearing Female Reporter 'Talk About Routes'",
#  'Trump Takes a First Step Toward Scrapping Obama’s Global Warming Policy',
#  'U.N. bans four ships over North Korea coal, U.S. delays four more',
#  'Woman Throws Drink On Lakers Fans Who Took A Knee During The Anthem',
#  '‘Blade Runner 2049’ Sputters at the Domestic Box Office',
#  "Victim in wheelchair says NY bombing felt like 'doomsday'",
#  'NFL Players Kneeling ‘a Protest Against America’',
#  'Bitcoin surges above $5,000 to new record high',
#  '2017 Fantasy Football IDP Rankings - Week 4',
#  "HAARP to 'make the sky glow' with radio waves over western Arctic starting Thursday",
#  'Game Photos: Michigan at Purdue',
#  'Organization May Be Forced to Return Paid Patriotism Funds Again',
#  'Video Surfaces of Dolphins OL Coach Chris Foerster Reportedly Doing Drugs Before a Team Meeting',
#  'CNN and Globalist Exposed - Steve Quayle and Alex Jones',
#  'PreseasonBlackhawks at Boston4-2 Loss Recap',
#  "Corker's tumultuous relationship with Trump",
#  '‘These people need to be protected’: Police won’t release info on lynching of 8-year-old biracial boy',
#  'President Donald Trump’s Schedule for Thursday, September 5, 2017',
#  'Dealership gives new truck to veteran who helped Las Vegas shooting victims',
#  'Mexican Radio Host’s Resignation Highlights Ties Between Government and Media',
#  'Breakingviews - Beijing’s closer embrace is bad news for Big Tech',
#  'Japan to restore neglected gardens abroad',
#  'How would you feel about this Blackhawks lineup?',
#  'Panasonic expects autonomous driving system launch in 2022',
#  '$1 5 Quadrillion Derivatives Collapse in 2015 Entire Financial System to Implode in An Hour!',
#  'Cider-Braised Pork Shoulder - Pork Stewed in a Creamy Apple Cider Sauce',
#  'Cannibals Arrested in Florida Claim Eating Human Flesh Cures Diabetes and Depression',
#  'Spain Catalan crisis: Reaction to Puigdemont from Madrid and Barcelona',
#  'Brazil agency says Bayer-Monsanto tie-up can hurt competition, urges conditions',
#  '9/29 Through the 40s: HBD Cannonball & Paul, Camnitz Clan, Game Stories',
#  "Brazil court freezes ex-leader Rousseff's assets over 2006 refinery deal",
#  'Sen. John McCain has brain cancer, aggressive tumor surgically removed',
#  'Trump Is So Busy Bashing NFL, He Forgot To Hire A Science Adviser',
#  'Steelers Ring the Bell 35 Times in Huge 26-9 Road Win Over the Ravens',
#  'Where Is The Relief Money For Texas Hurricane Victims? Please Share!',
#  'Las Vegas massacre: It could have been even worse',
#  "'Hell to pay' over water, food deliveries, Puerto Rico governor warns",
#  'Affleck apologizes for groping Hilarie Burton',
#  "Ashraf Ghani: Afghan president has 'worst job on Earth'",
#  "Defense challenges doctor's finding in Kim killing case",
#  '2017 Chicago Cubs regular season highlights to get you pumped for NLDS',
#  'Ravens Take Exception to The Boos',
#  'Odell Beckham Jr. Is Injured as Giants’ Season Keeps Spiraling',
#  'Catalan leader under pressure to drop independence',
#  'Solar cars begin race across Australian desert',
#  'Regular Season OpenerBlackhawks vs Penguins10-1 Win Recap',
#  'Andrew Black and the road to Exchange Betting',
#  'The Next Financial Crisis Is Not Far Away',
#  '64 YO Stephen Paddock Identified As The Gunman Behind LV Mass Shooting',
#  '10/7: Chuck Axed; HBD Brickyard, Adam, Moonlight Ace & Chuck; AS; Season Finales...',
#  '“Racist Propaganda”: Librarian Rejects Books Donated By Melania',
#  'Yves Saint Laurent designs get new airing at Paris museum',
#  'ISIS Releases “Hit List” Of 100 U.S. Military Personnel Urging Followers To “Hunt Them Down”',
#  'Kazuo Ishiguro keeps calm amid Nobel Prize frenzy',
#  'Apollo 17 and the mystery of the last moon landing, why haven’t we returned',
#  'All 3 Billion Yahoo Accounts Were Affected by 2013 Attack',
#  'Man Finds Note In SF Airport, You Won’t Believe What Was Inside',
#  'Waiver Worthy: Week 4: Wendell Smallwood, Sterling Shepard, Duke Johnson & More',
#  'Smart Devices are Listening to (and Saving) Everything You Say, Here’s How to Stop It',
#  'The Ditch List: Week 4 Fallout: Breaking Down Four Players It May Be Time To Cut Bait On',
#  "Brazil's congress sets up fund to cover lack of campaign finance",
#  'The Walking Dead Season 8: Season Premiere [sneak peak]',
#  'Iceland Becomes Smallest Nation to Qualify for World Cup',
#  'Worst Roller Coaster Accidents Caught On Video',
#  'Giant Glowing Spiral Shocks Residents In Russia',
#  "Avid Hunter Don Jr. On Gun Silencers: ‘It's Just A Great Instrument’",
#  "Trump says 'very important' NFL players stand for anthem Sunday",
#  'Seeing India Through a Contemporary Lens',
#  'Chicago Cubs clinch NL Central Division Title',
#  'Harvey Weinstein Draws Sharp Attacks From Late-Night Hosts',
#  "Terry Crews on why sexual assault survivors don't come forward",
#  'Documenting Sports With Tech, or It Didn’t Happen',
#  'Teacher Told Students They Were ‘Too Dark-Skinned’ To Play Lincoln',
#  'Diamondbacks take WILD N.L. Wild-Card Game, Will Face Dodgers Next',
#  'Chinese Police Orders Uyghur Muslims To Hand In The Holy Quran',
#  'Catalonia Independence Fight Produces Some Odd Bedfellows',
#  'Wildfire victim: We had 5 minutes to evacuate',
#  "Israeli spies 'watched Russian agents breach Kaspersky software'",
#  "Top Democrat questions Kellyanne Conway's air travel",
#  'Are the Niners Ready to Turn the Corner? Only Time Will Tell',
#  'Thursday Morning Briefing',
#  "Bar Owner Doesn't Think 'Lynch Kaepernick' Doormat Is Racist. Really?",
#  'Russia, China call for restraint after Trump comment on North Korea',
#  'Explosive Lawsuit Shows Saudi Arabia Funded a “Dry Run” for 9',
#  'Google Clips Automatically Identifies Everyone Including Your Pets',
#  'Trump’s Kids Allegedly Used Political Clout To Get Fraud Case Dropped',
#  'Kushner’s Lawyer Is So Smart He Emailed A Senate Letter To A Prankster',
#  "9/30 Expo Park-Forbes Field Era: Temple Cup, '08 Race, Mo Bros, Kiner Wallops, Herman Deal, K Mart",
#  'New York Police Operation Ends Side Career of Mickey D’s Night Manager',
#  'Rohingya, Harvey Weinstein, South Korea: Your Thursday Briefing',
#  'Students skate 352 miles during Chinese holiday week',
#  'Ellen DeGeneres Says She Will Never Host President Trump On Her Show',
#  'Emerging market tech stock boom gives fund managers a headache',
#  'Spain, Harvey Weinstein, Donald Trump: Your Thursday Briefing',
#  'Caitlyn Jenner confronts Jimmy Kimmel for making fun of her plan to pick OJ up from prison',
#  'What’s on TV Monday: ‘The Islands and the Whales’ and ‘Valor’',
#  "Trump continues NBC threats, says 'licenses must be challenged'",
#  'Over $971,000 spent on non-commercial air travel for Obama administration Interior secretaries',
#  'Puckin Hostile ShoutcastEpisode 91',
#  "Macron's public sector reforms spark nationwide strikes",
#  'Save The Children - A.F. Branco Cartoon',
#  'Ravens @ Raiders - Thursday',
#  'Yemenis See Turning Point After Ousting Qaeda Militants in South',
#  'Mac’s “Scraps” Continue to Impress',
#  'Aung San Suu Kyi Stripped Of Oxford Honor Amid Ethnic Cleansing Claims',
#  "10/5 Expo Park-Forbes Field: Bucs Win '60 Opener, Lose '27; Pud's 300; HBD Claude, Felix & Sarge; Grays Win WS",
#  'Cam Newton Tweets Out Apology Video After Laughing at Female Reporter',
#  'Turkish PM says Idlib operation aims to prevent migrant wave from Syria',
#  'Catalonia, Turkey, North Korea: Your Wednesday Briefing',
#  'Something Huge From Deep Space Is Coming To Earth And It Will Be Closer Than The Distance Between New York & Tokyo',
#  'Credit Agency Equifax Threatened To Pay Up In Bitcoin Or Else',
#  'Kobe Steel CEO says data-cheating may have spread beyond Japan as government orders probe',
#  'Kenyan opposition leader withdraws from repeat presidential poll',
#  'Trump: I have different attitude on NK',
#  'Sticker Proclaiming ‘KKK Wants You’ Found At A Portland High School',
#  'Japan transport ministry finds flawed procedures at five Nissan plants',
#  'Michigan State Spartans Break Arch-Rival Wolverines’ Hearts With HUGE Road Win',
#  'Bucs Finish Up Homestand on Winning Note 5-3',
#  'The week in 35 photos',
#  'Business leaders say no NAFTA better than bad deal',
#  'Qualcomm offers EU concessions over $38 billion NXP takeover bid',
#  'Category 6? If Hurricane Irma Becomes The Strongest Hurricane In History, It Could Wipe Entire Cities Off The Map',
#  "President Trump focuses anti-media ire on NBC after Tillerson 'moron' report",
#  'This High School Is Threatening To Ban Players Who Kneel During Anthem',
#  '2017 Fantasy Football Quarterback Rankings - Week 5',
#  "China's secret aid empire uncovered",
#  "Disney's Tiffany Thornton defends remarrying two years after husband died",
#  'What if Platforms Like Facebook Are Too Big to Regulate?',
#  'Steven Tyler denies having heart attack',
#  'New Video Emerges Raising Questions of Overlapping Gunfire at Las Vegas Concert',
#  "Showtime's Websites Hijacked Visitor's CPU Power To Mine Cryptocurrency",
#  "Fire survivor: 'I don't have any neighbours any more'",
#  'USS Indianapolis discovery: War hero and family reunite',
#  'OPEC says to reconvene meeting with U.S. on deal to cut oil output',
#  'Man Accused To Smuggling Drugs Inside His Dog, How It Got There Will Shock You!',
#  'Will Japan win the flying car race?',
#  'Exclusive: U.S. warship sails near islands Beijing claims in South China Sea - U.S. officials',
#  'Mexico quake leaves thousands stranded without a home',
#  "Fiscal test: As India's smaller firms struggle, Modi faces stimulus dilemma",
#  'Kushner’s Lawyer Is So Smart He Emailed A Senate Letter To A Prankster',
#  'Nationals Stage a Late Comeback, Perhaps Exorcising Postseason Demons',
#  'Let It Burn? Usher Cut a $1.1 MILLION Check to a Woman He Infected with Herpes [Court Documents Added]',
#  'U.S. still seeking explanation for arrest of staff in Turkey: ambassador',
#  'Chicago Cubs accomplish rare franchise feat with NL Central win',
#  '10/9: HBD Bob Moose,Cricket, Starling & Six More; RIP Tiger & Moose; Danny Hired; Hans Title',
#  "9/27 TRS-PNC Era: Bucs Clinch In '70 & '92, HBD Pedro & Vin, Giles Goes Wild, Game Stories",
#  "Post-Vegas, Conway blames Obama's ATF",
#  'MLB Post Season Monday: Who’s Playing and Where to Watch',
#  'Sheriff Won’t Charge The Teens Who Talked About Lynching A Student',
#  "Germany: 'No evidence' Kaspersky software used by Russians for hacks",
#  'Trump Successfully Introduced Nepotism Into The White House',
#  "Asian American rapper's startling comeback",
#  "CBS reporter: I didn't talk to Kaepernick about kneeling",
#  'Wake Up America, It’s Time To Repeal The Second Amendment',
#  'Hoping to Have Trump Cleared, Legal Team Eases Resistance to Inquiry',
#  'Man To Howard University Students: ‘It’s Not Murder If They’re Black’',
#  'Player To Monitor: Will Teoscar Hernandez Emerge As A Viable Fantasy Option?',
#  'Young Dread, One of the Most Followed Artists, Has Released His New Album',
#  'Lambeau Field has become a House of Horrors for the Chicago Bears',
#  'US Seeks to Monopolize Cyberwarfare',
#  'Jets Beat Dolphins; NY Jets Podcast',
#  'President of Brazilian Olympic Committee arrested',
#  '10 Important Stories From 09/28/17 Box Scores: Is Pham For Real, The Outlook For E. Rodriguez & More',
#  'Jared Kushner Has Been Reportedly Voting As A Woman For 8 Years',
#  'Paul Ryan Is The Last Person To Blame Mass Shootings On Mental Illness',
#  "'Blade Runner 2049' has great ambition, some glitches",
#  'Russians in Silicon Valley Can’t Shake Hacking’s Shadow',
#  'Trump Bemoans ‘Little Appreciation’ As San Juan Mayor Begs For Water',
#  'American Woman and Family Held for 5 Years in Afghanistan Freed From Militants',
#  'Report: Bannon said Trump has 30% chance of completing full term',
#  'Stephen Paddock: What we know about the Las Vegas gunman',
#  'Trump nominee defends move to void gay worker protections',
#  'OPEC again raises demand forecast for its oil, points to 2018 deficit',
#  'Dave Doeren has finally gotten that signature win',
#  'Equifax Exposed: Major Breach of Data from Major Credit Bureau',
#  'Passing Game Film Review - McFrown - Week 3 (Dolphins)',
#  'Iceland 2-0 Kosovo',
#  '10 Important Stories From 09/24/17 Box Scores: Devers Delivering, Anderson/Giolito Are Regression Risks & More',
#  'Fires kill couple married for 75 years, leave 250+ missing',
#  'Chicago Based Rock Band Introduce Us To "The Lost Art OF Empathy"',
#  'Two U.S. B-1 bombers conduct training mission in vicinity of Sea of Japan',
#  'This High School Is Threatening To Ban Players Who Kneel During Anthem',
#  '2017 Fantasy Football Team Defense Rankings - Week 5',
#  'Las Vegas Shooting From 64th Floor of Mandalay Bay (Video)',
#  'Will A Strong Finish/Postseason Keep Kris Bryant As A 2018 1st Round Pick?',
#  'The U.S. Government Is Suing People For Requesting Public Records',
#  'NSFW Vegas Shooting Victims – Graphic and Gore',
#  '2017 Fantasy Football Team Defense Rankings - Week 4',
#  'Brandon Saad records hat trick in first game back with Chicago Blackhawks',
#  'Harvey Weinstein: Wife Georgina Chapman leaves accused producer',
#  'Betting on CS GO With Bitcoin',
#  'Police shoot at actor dressed as bank robber in Indiana',
#  'Colin Kaepernick: From one man kneeling to a movement dividing a country',
#  'E.U., Citing Amazon and Apple, Tells Nations to Collect Tax',
#  "Fire Chief Calls Pittsburgh Steelers Coach A 'No good N*****'",
#  "They'll wash the blood away, but won't forget",
#  'Gun control debate enters country music community',
#  'Military Is Waiting Longer Before Force-Feeding Hunger Strikers, Detainees Say',
#  'IRS Awards Multi-Million Dollar Fraud-Prevention Contract To Equifax Who Was Hacked TWICE',
#  'Tech and Real Estate Lift the Fortunes of China’s Richest',
#  'Japanese Grand Prix: Lewis Hamilton wins as Sebastian Vettel retires',
#  'At Route 91 Harvest, these survivors watched their loved ones die',
#  'What is Joe Biden up to?',
#  "Joe Biden's happy center never existed",
#  "UK Supermarket Becomes World's First to Offer Cashless Checkout with Finger Vein Scan",
#  'Souleye, New Age Hip Hop Rapper, Announces the Eagerly Awaited Album: WILDMAN Releasing September 22, 2017!',
#  "See what it's like to be a smokejumper",
#  'Jordan Howard has Fought His Whole Career for the Tough Yards',
#  '10 Important Stories From 09/26/17 Box Scores: Montgomery’s Strong Start, Harper’s Return & More',
#  "Lilly's breast cancer drug fails to help lung patients",
#  'Virginia’s hammering of Boise State changes outlook for the season.',
#  '$998 to Say Hello to Dolly? That’s the Price for Some Front Row Seats',
#  'Alex Collins Worth a Start?',
#  '2017 Fantasy Football IDP Rankings - Week 5',
#  'Virginia Tech is right on schedule despite loss to Clemson.',
#  'Odell Beckham Jr. on a Nike-Powered Swing Through SoHo',
#  "'Hair' gets a little new styling for the age of Trump",
#  'Amazing F-16 Night Takeoff',
#  'Israel’s Foreign Agents Don’t Register, Why Should Russia’s?',
#  'Rapper Nelly arrested over alleged tour bus rape',
#  'Senate bill to clear obstacles to self-driving cars advances',
#  'Chinese citizens buying opulent mansions in US',
#  'Puckin Hostile Shoutcast - Episode 90',
#  'John Green Tells a Story of Emotional Pain and Crippling Anxiety. His Own.',
#  "Disney's Tiffany Thornton defends remarrying two years after husband died",
#  'North Korean Leader Hails Nuclear Arsenal as ‘Powerful Deterrent’',
#  'Yankees Pounce on Indians’ Errors and Send Series to Game 5',
#  ...]

# %%
df.Headline.unique()
# Out:
# array(['Four ways Bob Corker skewered Donald Trump',
#        "Linklater's war veteran comedy speaks to modern America, says star",
#        'Trump’s Fight With Corker Jeopardizes His Legislative Agenda',
#        ...,
#        'Hervé Leroux, Creator of the Hervé Léger Bandage Dress, Dies at 60',
#        'Trump Jr. Is Soon To Give A 30-Minute Speech For $100,000',
#        'Vice President Mike Pence Leaves NFL Game Because of Anti-American Protests'],
#       dtype=object)

# %%
df['Label'] = df['Label'].replace({0:'Fake', 1:'Real'})

# %%
y=df['Label']

# %%
y.unique()
# Out:
# array(['Real', 'Fake'], dtype=object)

# %%
y=list(y)

# %%
y
# Out:
# ['Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Fake',
#  'Real',
#  'Fake',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Fake',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Fake',
#  'Real',
#  'Real',
#  'Real',
#  'Real',
#  ...]

# %%
type(y)
# Out:
# list

# %%
df.Label.unique()
# Out:
# array(['Real', 'Fake'], dtype=object)

# %%
# Text tokenization
# vectorizing text, turning each text into sequence of integers

tokenizer = Tokenizer(num_words=None,char_level=True,oov_token='UNK')
tokenizer.fit_on_texts(x)

# %%
# convert to sequence of integers
x = tokenizer.texts_to_sequences(x)

# %%
print(x[0])
# Out:
# [19, 7, 15, 10, 2, 20, 4, 22, 5, 2, 21, 7, 21, 2, 12, 7, 10, 23, 3, 10, 2, 5, 23, 3, 20, 3, 10, 3, 13, 2, 13, 7, 9, 4, 11, 13, 2, 6, 10, 15, 16, 17]

# %%
x = np.array(x)
y = np.array(y)
# pad sequences at the beginning of each sequence with 0's
# for example if SEQUENCE_LENGTH=4:
# [[5, 3, 2], [5, 1, 2, 3], [3, 4]]
# will be transformed to:
# [[0, 5, 3, 2], [5, 1, 2, 3], [0, 0, 3, 4]]
x = pad_sequences(x, maxlen=SEQUENCE_LENGTH)

# %%
#y = [label in[label] for label in y ]
#y = to_categorical(y)
y = [ label2int[label] for label in y ]
y = to_categorical(y)

# %%
 print(y[0])
# Out:
# [0. 1.]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=7)

# %%
def get_embedding_vectors(tokenizer, dim=100):
    embedding_index = {}
    with open(f"glove.6B.{dim}d.txt", encoding='utf8') as f:
        for line in tqdm.tqdm(f, "Reading GloVe"):
            values = line.split()
            word = values[0]
            vectors = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = vectors

    word_index = tokenizer.word_index
    embedding_matrix = np.zeros((len(word_index)+1, dim))
    for word, i in word_index.items():
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            # words not found will be 0s
            embedding_matrix[i] = embedding_vector
            
    return embedding_matrix

# %%
import tensorflow as tf
def get_model(tokenizer, lstm_units):
    """
    Constructs the model,
    Embedding vectors => LSTM => 2 output Fully-Connected neurons with softmax activation
    """
    # get the GloVe embedding vectors
    embedding_matrix = get_embedding_vectors(tokenizer)
    model = Sequential()
    model.add(Embedding(len(tokenizer.word_index)+1,
              EMBEDDING_SIZE,
              weights=[embedding_matrix],
              trainable=False,
              input_length=SEQUENCE_LENGTH))

    model.add(LSTM(lstm_units, recurrent_dropout=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(2, activation="softmax"))
    # compile as rmsprop optimizer
    # aswell as with recall metric
    model.compile(optimizer="rmsprop", loss="binary_crossentropy",
                  metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    model.summary()
    return model

# %%
model = get_model(tokenizer=tokenizer, lstm_units=128)
# Out:
# Reading GloVe: 400000it [00:16, 24850.71it/s]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 100)          7600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 125,106
# Trainable params: 117,506
# Non-trainable params: 7,600
# _________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint("Real_or_Fake_news{val_loss:.2f}", save_best_only=True,verbose=1)
# for better visualization
tensorboard = TensorBoard(f"Real_or_Fake_news{time.time()}")
# print our data shapes
print("X_train.shape:", X_train.shape)
print("X_test.shape:", X_test.shape)
print("y_train.shape:", y_train.shape)
print("y_test.shape:", y_test.shape)
# train the model
model.fit(X_train, y_train, validation_data=(X_test, y_test),batch_size=32, epochs=100,verbose=1)
# Out:
# X_train.shape: (2658, 100)
# X_test.shape: (1330, 100)
# y_train.shape: (2658, 2)
# y_test.shape: (1330, 2)
# Train on 2658 samples, validate on 1330 samples
# Epoch 1/100
# 2658/2658 [==============================] - 11s 4ms/step - loss: 0.6862 - accuracy: 0.5549 - precision: 0.5417 - recall: 0.5417 - val_loss: 0.6671 - val_accuracy: 0.5677 - val_precision: 0.5557 - val_recall: 0.5557
# Epoch 2/100
# 2658/2658 [==============================] - 10s 4ms/step - loss: 0.6568 - accuracy: 0.5926 - precision: 0.5707 - recall: 0.5707 - val_loss: 0.6569 - val_accuracy: 0.5880 - val_precision: 0.5741 - val_recall: 0.5741
# Epoch 3/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.6453 - accuracy: 0.6046 - precision: 0.5794 - recall: 0.5794 - val_loss: 0.6467 - val_accuracy: 0.5992 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 4/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.6246 - accuracy: 0.6260 - precision: 0.5887 - recall: 0.5887 - val_loss: 0.9935 - val_accuracy: 0.5098 - val_precision: 0.5883 - val_recall: 0.5883
# Epoch 5/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.6297 - accuracy: 0.6230 - precision: 0.5871 - recall: 0.5871 - val_loss: 0.6899 - val_accuracy: 0.5805 - val_precision: 0.5900 - val_recall: 0.5900
# Epoch 6/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.6063 - accuracy: 0.6527 - precision: 0.5937 - recall: 0.5937 - val_loss: 0.6654 - val_accuracy: 0.5895 - val_precision: 0.5968 - val_recall: 0.5968
# Epoch 7/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.0314 - accuracy: 0.9891 - precision: 0.8541 - recall: 0.8541 - val_loss: 0.9861 - val_accuracy: 0.8098 - val_precision: 0.8545 - val_recall: 0.8545
# Epoch 93/100
# 2658/2658 [==============================] - 9s 4ms/step - loss: 0.0259 - accuracy: 0.9891 - precision: 0.8549 - recall: 0.8549 - val_loss: 0.9368 - val_accuracy: 0.8150 - val_precision: 0.8553 - val_recall: 0.8553
# Epoch 94/100
# 2658/2658 [==============================] - 9s 4ms/step - loss: 0.0292 - accuracy: 0.9898 - precision: 0.8558 - recall: 0.8558 - val_loss: 0.9714 - val_accuracy: 0.8165 - val_precision: 0.8561 - val_recall: 0.8561
# Epoch 95/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.0283 - accuracy: 0.9906 - precision: 0.8566 - recall: 0.8566 - val_loss: 0.9413 - val_accuracy: 0.8248 - val_precision: 0.8570 - val_recall: 0.8570
# Epoch 96/100
# 2658/2658 [==============================] - 9s 4ms/step - loss: 0.0331 - accuracy: 0.9898 - precision: 0.8574 - recall: 0.8574 - val_loss: 0.9485 - val_accuracy: 0.8218 - val_precision: 0.8578 - val_recall: 0.8578
# Epoch 97/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.0234 - accuracy: 0.9913 - precision: 0.8582 - recall: 0.8582 - val_loss: 1.0618 - val_accuracy: 0.8090 - val_precision: 0.8585 - val_recall: 0.8585
# Epoch 98/100
# 2658/2658 [==============================] - 10s 4ms/step - loss: 0.0331 - accuracy: 0.9891 - precision: 0.8589 - recall: 0.8589 - val_loss: 1.0196 - val_accuracy: 0.8083 - val_precision: 0.8593 - val_recall: 0.8593
# Epoch 99/100
# 2658/2658 [==============================] - 9s 4ms/step - loss: 0.0317 - accuracy: 0.9880 - precision: 0.8596 - recall: 0.8596 - val_loss: 0.8754 - val_accuracy: 0.8233 - val_precision: 0.8600 - val_recall: 0.8600
# Epoch 100/100
# 2658/2658 [==============================] - 9s 3ms/step - loss: 0.0308 - accuracy: 0.9898 - precision: 0.8604 - recall: 0.8604 - val_loss: 0.9467 - val_accuracy: 0.8233 - val_precision: 0.8607 - val_recall: 0.8607

# %%
# get the loss and metrics
result = model.evaluate(X_test, y_test)
# extract those
loss = result[0]
accuracy = result[1]
precision = result[2]
recall = result[3]
# Out:
# 1330/1330 [==============================] - 1s 1ms/step

# %%
print(f"[+] Accuracy: {accuracy*100:.2f}%")
print(f"[+] Precision:   {precision*100:.2f}%")
print(f"[+] Recall:   {recall*100:.2f}%")
# Out:
# [+] Accuracy: 82.33%
# [+] Precision:   86.06%
# [+] Recall:   86.06%

# %%
def get_predictions(text):
    sequence = tokenizer.texts_to_sequences([text])
    # pad the sequence
    sequence = pad_sequences(sequence, maxlen=SEQUENCE_LENGTH)
    # get the prediction
    prediction = model.predict(sequence)[0]
    # one-hot encoded vector, revert using np.argmax
    return int2label[np.argmax(prediction)]

# %%
text=str(input("enter the statement: "))
# Out:
# enter the statement: Linklater's war veteran comedy speaks to modern America, says star

# %%
print(get_predictions(text))
# Out:
# Real
